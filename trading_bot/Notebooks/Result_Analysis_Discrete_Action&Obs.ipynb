# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

# %% [markdown]
# ### LOAD TRAIN AND TEST SET

# %%
train = pd.read_csv("../Data/train_ZNH0_MBO.csv")
test = pd.read_csv("../Data/test_ZNH0_MBO.csv")

# %%
fig, axs = plt.subplots(1, 1,figsize=(30, 10))
train['L1bid_price'][:1494000].plot()

# %%
fig, axs = plt.subplots(1, 1,figsize=(30, 10))
test['L1bid_price'].plot()

# %% [markdown]
# ### Load Results

# %%
simple_disc_seed1 = pd.read_csv('../Results/resultsimple_buy_sellaccb_nosec_action_discrete_bid_askdiscrete2020-08-10 07:49:38.502898.csv')
simple_disc_seed2 = pd.read_csv('../Results/resultsimple_buy_sellaccb_nosec_action_discrete_bid_askdiscrete2020-08-10 07:55:09.282837.csv')
midpoint_disc_seed1 = pd.read_csv('../Results/resultsimple_buy_sell_at_midpointaccb_nosec_action_discrete_bid_askdiscrete2020-08-10 07:51:17.317529.csv')
midpoint_disc_seed2 = pd.read_csv('../Results/resultsimple_buy_sell_at_midpointaccb_nosec_action_discrete_bid_askdiscrete2020-08-10 07:56:09.730920.csv')

# %% [markdown]
# ### Plot Rewards

# %%
fig, axs = plt.subplots(4, 1,figsize=(30, 30))
axs[0].plot(simple_disc_seed1['Reward'])
axs[0].title.set_text('simple_cont_seed1')

axs[1].plot(simple_disc_seed2['Reward'])
axs[1].title.set_text('simple_cont_seed2')

axs[2].plot(midpoint_disc_seed1['Reward'])
axs[2].title.set_text('midpoint_cont_seed1')

axs[3].plot(midpoint_disc_seed2['Reward'])
axs[3].title.set_text('midpoint_cont_seed2')

# %% [markdown]
# ### Net Worth

# %%
fig, axs = plt.subplots(4, 1,figsize=(30, 30))
axs[0].plot(simple_disc_seed1['Net_Worth'])
axs[0].title.set_text('simple_cont_seed1')

axs[1].plot(simple_disc_seed2['Net_Worth'])
axs[1].title.set_text('simple_cont_seed2')

axs[2].plot(midpoint_disc_seed1['Net_Worth'])
axs[2].title.set_text('midpoint_cont_seed1')

axs[3].plot(midpoint_disc_seed2['Net_Worth'])
axs[3].title.set_text('midpoint_cont_seed2')

# %% [markdown]
# ### Final Net Worth

# %%
print(simple_disc_seed1['Net_Worth'][len(simple_disc_seed1['Net_Worth'])-1])
print(simple_disc_seed2['Net_Worth'][len(simple_disc_seed2['Net_Worth'])-1])
print(midpoint_disc_seed1['Net_Worth'][len(midpoint_disc_seed1['Net_Worth'])-1])
print(midpoint_disc_seed2['Net_Worth'][len(midpoint_disc_seed2['Net_Worth'])-1])
# Out:
# 975063.6796875
# 974290.765625
# 1013465.84375
# 1046935.5703125

# %% [markdown]
# ### PnL

# %%
print(simple_disc_seed1['Net_Worth'][len(simple_disc_seed1['Net_Worth'])-1] - simple_disc_seed1['Net_Worth'][0])

print(simple_disc_seed2['Net_Worth'][len(simple_disc_seed2['Net_Worth'])-1] - simple_disc_seed2['Net_Worth'][0])

print(midpoint_disc_seed1['Net_Worth'][len(midpoint_disc_seed1['Net_Worth'])-1] - midpoint_disc_seed1['Net_Worth'][0])

print(midpoint_disc_seed2['Net_Worth'][len(midpoint_disc_seed2['Net_Worth'])-1] - midpoint_disc_seed2['Net_Worth'][0])
# Out:
# -24936.3203125
# -25709.234375
# 13465.84375
# 46935.5703125

# %% [markdown]
# ### Account Balance

# %%
fig, axs = plt.subplots(4, 1,figsize=(30, 30))
axs[0].plot(simple_disc_seed1['Account_Balance'])
axs[0].title.set_text('simple_disc_seed1')

axs[1].plot(simple_disc_seed2['Account_Balance'])
axs[1].title.set_text('simple_disc_seed2')

axs[2].plot(midpoint_disc_seed1['Account_Balance'])
axs[2].title.set_text('midpoint_disc_seed1')

axs[3].plot(midpoint_disc_seed2['Account_Balance'])
axs[3].title.set_text('midpoint_disc_seed2')

# %% [markdown]
# ### Value Of Sec

# %%
fig, axs = plt.subplots(4, 1,figsize=(30, 30))
axs[0].plot(simple_disc_seed1['Val_Sec'])
axs[0].title.set_text('simple_cont_seed1')

axs[1].plot(simple_disc_seed2['Val_Sec'])
axs[1].title.set_text('simple_cont_seed2')

axs[2].plot(midpoint_disc_seed1['Val_Sec'])
axs[2].title.set_text('midpoint_cont_seed1')

axs[3].plot(midpoint_disc_seed2['Val_Sec'])
axs[3].title.set_text('midpoint_cont_seed2')

# %% [markdown]
# ### Final Sec Held

# %%
print(simple_disc_seed1['Sec'][len(simple_disc_seed1['Net_Worth'])-1])
print(simple_disc_seed2['Sec'][len(simple_disc_seed2['Net_Worth'])-1])
print(midpoint_disc_seed1['Sec'][len(midpoint_disc_seed1['Net_Worth'])-1])
print(midpoint_disc_seed2['Sec'][len(midpoint_disc_seed2['Net_Worth'])-1])
# Out:
# 52673
# 1566
# 166726
# 449261
