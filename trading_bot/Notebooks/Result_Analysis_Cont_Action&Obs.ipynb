# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

# %% [markdown]
# ### LOAD TRAIN AND TEST SET

# %%
train = pd.read_csv("../Data/train_ZNH0_MBO.csv")
test = pd.read_csv("../Data/test_ZNH0_MBO.csv")

# %%
fig, axs = plt.subplots(1, 1,figsize=(30, 10))
train['L1bid_price'][:1494000].plot()

# %%
fig, axs = plt.subplots(1, 1,figsize=(30, 10))
test['L1bid_price'].plot()

# %% [markdown]
# ### Load Results

# %%
simple_cont_seed1 = pd.read_csv('../Results/resultsimple_buy_sellaccb_nosec_action_continous_bid_askcontinuous_1action2020-08-10 08:05:22.738987.csv')
simple_cont_seed2 = pd.read_csv('../Results/resultsimple_buy_sellaccb_nosec_action_continous_bid_askcontinuous_1action2020-08-10 08:05:42.884372.csv')
midpoint_cont_seed1 = pd.read_csv('../Results/resultsimple_buy_sell_at_midpointaccb_nosec_action_continous_bid_askcontinuous_1action2020-08-10 08:11:56.557253.csv')
midpoint_cont_seed2 = pd.read_csv('../Results/resultsimple_buy_sell_at_midpointaccb_nosec_action_continous_bid_askcontinuous_1action2020-08-10 08:05:58.287339.csv')

# %% [markdown]
# ### Plot Rewards

# %%
fig, axs = plt.subplots(4, 1,figsize=(30, 30))
axs[0].plot(simple_cont_seed1['Reward'])
axs[0].title.set_text('simple_cont_seed1')

axs[1].plot(simple_cont_seed2['Reward'])
axs[1].title.set_text('simple_cont_seed2')

axs[2].plot(midpoint_cont_seed1['Reward'])
axs[2].title.set_text('midpoint_cont_seed1')

axs[3].plot(midpoint_cont_seed2['Reward'])
axs[3].title.set_text('midpoint_cont_seed2')

# %% [markdown]
# ### Net Worth

# %%
fig, axs = plt.subplots(4, 1,figsize=(30, 30))
axs[0].plot(simple_cont_seed1['Net_Worth'])
axs[0].title.set_text('simple_cont_seed1')

axs[1].plot(simple_cont_seed2['Net_Worth'])
axs[1].title.set_text('simple_cont_seed2')

axs[2].plot(midpoint_cont_seed1['Net_Worth'])
axs[2].title.set_text('midpoint_cont_seed1')

axs[3].plot(midpoint_cont_seed2['Net_Worth'])
axs[3].title.set_text('midpoint_cont_seed2')

# %% [markdown]
# ### Final Net Worth

# %%
print(simple_cont_seed1['Net_Worth'][len(simple_cont_seed1['Net_Worth'])-1])
print(simple_cont_seed2['Net_Worth'][len(simple_cont_seed2['Net_Worth'])-1])
print(midpoint_cont_seed1['Net_Worth'][len(midpoint_cont_seed1['Net_Worth'])-1])
print(midpoint_cont_seed2['Net_Worth'][len(midpoint_cont_seed2['Net_Worth'])-1])
# Out:
# 1997416.7421875
# 940805.578125
# 1194086.3984375
# 1032844.0234375

# %% [markdown]
# ### PnL

# %%
print(simple_cont_seed1['Net_Worth'][len(simple_cont_seed1['Net_Worth'])-1] - simple_cont_seed1['Net_Worth'][0])

print(simple_cont_seed2['Net_Worth'][len(simple_cont_seed2['Net_Worth'])-1] - simple_cont_seed2['Net_Worth'][0])

print(midpoint_cont_seed1['Net_Worth'][len(midpoint_cont_seed1['Net_Worth'])-1] - midpoint_cont_seed1['Net_Worth'][0])

print(midpoint_cont_seed2['Net_Worth'][len(midpoint_cont_seed2['Net_Worth'])-1] - midpoint_cont_seed2['Net_Worth'][0])
# Out:
# 997416.78125
# -59194.421875
# 194086.3984375
# 32844.0234375

# %% [markdown]
# ### Account Balance

# %%
fig, axs = plt.subplots(4, 1,figsize=(30, 30))
axs[0].plot(simple_cont_seed1['Account_Balance'])
axs[0].title.set_text('simple_cont_seed1')

axs[1].plot(simple_cont_seed2['Account_Balance'])
axs[1].title.set_text('simple_cont_seed2')

axs[2].plot(midpoint_cont_seed1['Account_Balance'])
axs[2].title.set_text('midpoint_cont_seed1')

axs[3].plot(midpoint_cont_seed2['Account_Balance'])
axs[3].title.set_text('midpoint_cont_seed2')

# %% [markdown]
# ### Value Of Sec

# %%
fig, axs = plt.subplots(4, 1,figsize=(30, 30))
axs[0].plot(simple_cont_seed1['Val_Sec'])
axs[0].title.set_text('simple_cont_seed1')

axs[1].plot(simple_cont_seed2['Val_Sec'])
axs[1].title.set_text('simple_cont_seed2')

axs[2].plot(midpoint_cont_seed1['Val_Sec'])
axs[2].title.set_text('midpoint_cont_seed1')

axs[3].plot(midpoint_cont_seed2['Val_Sec'])
axs[3].title.set_text('midpoint_cont_seed2')

# %% [markdown]
# ### Final Sec Held

# %%
print(simple_cont_seed1['Sec'][len(simple_cont_seed1['Net_Worth'])-1])
print(simple_cont_seed2['Sec'][len(simple_cont_seed2['Net_Worth'])-1])
print(midpoint_cont_seed1['Sec'][len(midpoint_cont_seed1['Net_Worth'])-1])
print(midpoint_cont_seed2['Sec'][len(midpoint_cont_seed2['Net_Worth'])-1])
# Out:
# 11113135
# 88892
# 1067993
# 53791
