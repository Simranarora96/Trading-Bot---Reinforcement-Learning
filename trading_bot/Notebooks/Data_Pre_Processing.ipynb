# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_pickle('data/levels-20191101')

# %%
df
# Out:
#                                 time          sym   L1bid_price  L1bid_size  \
# 0      2019-10-31 21:00:00.077903697  b'GCZ9:MBO'  15152.000000           2
# 135933 2019-10-31 21:00:00.084010111  b'UBZ9:MBO'    189.531250           4
# 680564 2019-10-31 21:00:00.084010111  b'ZFZ9:MBO'    119.203125          14
# 711951 2019-10-31 21:00:00.084010111  b'ZNZ9:MBO'    130.296875         246
# 463313 2019-10-31 21:00:00.084010111  b'TNZ9:MBO'    142.093750          15
# ...                              ...          ...           ...         ...
# 752468 2019-11-01 21:00:00.084227369  b'UBZ9:MBO'    189.281250           1
# 175262 2019-11-01 21:00:00.084227369  b'ZNZ9:MBO'    130.109375          80
# 680563 2019-11-01 21:00:00.084227369  b'ZBZ9:MBO'    160.968750           5
# 135932 2019-11-01 21:00:00.084227369  b'TNZ9:MBO'    141.843750           9
# 749790 2019-11-01 21:00:00.084227369  b'ZTZ9:MBO'    107.734375         117
#
# ...

# %%
df.describe()
# Out:
#         L1bid_price    L1bid_size   L1ask_price    L1ask_size   L2bid_price  \
# count  1.174979e+07  1.174979e+07  1.174979e+07  1.174979e+07  1.174979e+07
# mean   6.298679e+03  1.559192e+03  6.299079e+03  1.541855e+03  6.298318e+03
# std    5.841543e+03  3.478940e+03  5.841926e+03  3.366740e+03  5.841197e+03
# min    1.076797e+02  1.000000e+00  1.076836e+02  1.000000e+00  1.076758e+02
# 25%    1.303125e+02  4.600000e+01  1.303438e+02  4.800000e+01  1.302969e+02
# 50%    9.844000e+03  3.440000e+02  9.844500e+03  3.800000e+02  9.843500e+03
# 75%    9.856500e+03  1.302000e+03  9.857500e+03  1.431000e+03  9.856000e+03
# max    1.520200e+04  4.966900e+04  1.519000e+04  5.575300e+04  1.518600e+04
#
#          L2bid_size   L2ask_price    L2ask_size   L3bid_price    L3bid_size  \
# count  1.174979e+07  1.174979e+07  1.174979e+07  1.174979e+07  1.174979e+07
# mean   8.183040e+02  6.299440e+03  7.200432e+02  6.297957e+03  5.727294e+02
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11749791 entries, 0 to 749790
# Data columns (total 22 columns):
# time           datetime64[ns]
# sym            object
# L1bid_price    float64
# L1bid_size     int64
# L1ask_price    float64
# L1ask_size     int64
# L2bid_price    float64
# L2bid_size     int64
# L2ask_price    float64
# L2ask_size     int64
# L3bid_price    float64
# L3bid_size     int64
# L3ask_price    float64
# L3ask_size     int64
# L4bid_price    float64
# L4bid_size     int64
# L4ask_price    float64
# L4ask_size     int64
# L5bid_price    float64
# L5bid_size     int64
# L5ask_price    float64
# L5ask_size     int64
# dtypes: datetime64[ns](1), float64(10), int64(10), object(1)
# memory usage: 2.0+ GB

# %%
df2 = pd.read_pickle('data/levels-20191201')

# %%
df2
# Out:
#                             time          sym  L1bid_price  L1bid_size  \
# 31 2019-12-01 20:00:12.272613957  b'ZFZ9:MBO'   118.632812          10
# 60 2019-12-01 20:00:12.272613957  b'ZTH0:MBO'   107.781250          85
# 38 2019-12-01 20:00:12.272613957  b'ZNH0:MBO'   129.390625          53
# 62 2019-12-01 20:00:12.272613957  b'ZTZ9:MBO'   107.562500           9
# 28 2019-12-01 20:00:12.272613957  b'ZFH0:MBO'   118.960938          18
# ..                           ...          ...          ...         ...
# 35 2019-12-01 22:29:09.873106547  b'ZFZ9:MBO'   118.632812          10
# 36 2019-12-01 22:29:09.873107597  b'ZFZ9:MBO'   118.632812          10
# 37 2019-12-01 22:29:11.118561729  b'ZFZ9:MBO'   118.632812          10
# 42 2019-12-01 22:29:47.597989873  b'ZNH0:MBO'   129.562500          95
# 61 2019-12-01 22:29:56.332551145  b'ZTH0:MBO'   107.816406          83
#
#     L1ask_price  L1ask_size  L2bid_price  L2bid_size  L2ask_price  L2ask_size  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 31 to 61
# Data columns (total 22 columns):
# time           64 non-null datetime64[ns]
# sym            64 non-null object
# L1bid_price    64 non-null float64
# L1bid_size     64 non-null int64
# L1ask_price    61 non-null float64
# L1ask_size     61 non-null float64
# L2bid_price    63 non-null float64
# L2bid_size     63 non-null float64
# L2ask_price    61 non-null float64
# L2ask_size     61 non-null float64
# L3bid_price    61 non-null float64
# L3bid_size     61 non-null float64
# L3ask_price    61 non-null float64
# L3ask_size     61 non-null float64
# L4bid_price    60 non-null float64
# L4bid_size     60 non-null float64
# L4ask_price    56 non-null float64
# L4ask_size     56 non-null float64
# L5bid_price    60 non-null float64
# L5bid_size     60 non-null float64
# L5ask_price    55 non-null float64
# L5ask_size     55 non-null float64
# dtypes: datetime64[ns](1), float64(19), int64(1), object(1)
# ...

# %%
frames = [df, df2]

# %%
frame = [df]

# %%
data_array = ['levels-20191201',
'levels-20191202',
'levels-20191205',
'levels-20191206',
'levels-20191207',
'levels-20191209',
'levels-20191210',
'levels-20191212',
'levels-20191215',
'levels-20191216',
'levels-20191217',
'levels-20191218',
'levels-20191219',
'levels-20191221',
'levels-20191222',
'levels-20191223',
'levels-20191227',
'levels-20191228']

# %%
frame = []
for data in data_array:
    frame.append(pd.read_pickle('data/'+data))

# %%
result = pd.concat(frame)

# %%
result.to_csv('data/concat.csv')

# %%
result.info()
